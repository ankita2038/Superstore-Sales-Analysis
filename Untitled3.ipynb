# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b66b053a-8f3e-44e7-a8f2-593aee977529" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b66b053a-8f3e-44e7-a8f2-593aee977529">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.listdir()
# Out:
# ['.config', 'superstore_final_dataset (1).csv', 'sample_data']

# %%
df = pd.read_csv("superstore_final_dataset (1).csv", encoding="latin1")

df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
print(df.shape)

df.info()

df.describe()
# Out:
# (9800, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   object
#  3   Ship_Date      9800 non-null   object
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub_Category   9800 non-null   object
#  16  Product_Name   9800 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row_ID            0
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %%
print("Duplicate Rows :", df.duplicated().sum())

df.drop_duplicates(inplace=True)
# Out:
# Duplicate Rows : 0

# %%
df.columns
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d/%m/%Y')
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'], format='%d/%m/%Y')

# %%
df.columns
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   datetime64[ns]
#  3   Ship_Date      9800 non-null   datetime64[ns]
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub_Category   9800 non-null   object
#  16  Product_Name   9800 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales'],
#       dtype='object')

# %% [markdown]
# Monthly Sales Trend

# %%
# Create Month column
df['Month'] = df['Order_Date'].dt.month_name()

monthly_sales = df.groupby('Month')['Sales'].sum()

# Sort months in calendar order
month_order = ['January','February','March','April','May','June',
               'July','August','September','October','November','December']

monthly_sales = monthly_sales.reindex(month_order)

plt.figure(figsize=(12,5))

monthly_sales.plot(marker='o')

plt.title("Monthly Sales Trend")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.grid(True)

plt.show()

# %% [markdown]
# Sales by State

# %%
top_state = df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))

top_state.plot(kind='bar')

plt.title("Top 10 States by Sales")

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Sales by City

# %%
top_city = df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))

top_city.plot(kind='bar')

plt.title("Top 10 Cities by Sales")

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Sales by Sub-Category

# %%
subcategory = df.groupby('Sub_Category')['Sales'].sum().sort_values()

plt.figure(figsize=(10,8))

subcategory.plot(kind='barh')

plt.title("Sales by Sub Category")

plt.xlabel("Sales")

plt.show()

# %% [markdown]
# Top 10 Products

# %%
top_products = df.groupby('Product_Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))

top_products.plot(kind='bar')

plt.title("Top 10 Products")

plt.ylabel("Sales")

plt.xticks(rotation=75)

plt.show()

# %% [markdown]
# Bottom 10 Products

# %%
bottom_products = df.groupby('Product_Name')['Sales'].sum().sort_values().head(10)

plt.figure(figsize=(12,6))

bottom_products.plot(kind='bar')

plt.title("Bottom 10 Products")

plt.ylabel("Sales")

plt.xticks(rotation=75)

plt.show()

# %% [markdown]
# Orders by Region

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x='Region')

plt.title("Orders by Region")

plt.show()

# %% [markdown]
# Ship Mode Analysis

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x='Ship_Mode')

plt.title("Orders by Ship Mode")

plt.xticks(rotation=20)

plt.show()

# %% [markdown]
# Customer Segment Analysis

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()

plt.figure(figsize=(7,5))

segment_sales.plot(kind='bar')

plt.title("Sales by Customer Segment")

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(6,4))

numeric = df.select_dtypes(include=['int64','float64'])

sns.heatmap(
    numeric.corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# Top 10 Customers by Sales

# %%
top_customers = df.groupby('Customer_Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))

top_customers.plot(kind='bar', color='teal')

plt.title("Top 10 Customers by Sales")
plt.xlabel("Customer Name")
plt.ylabel("Total Sales")
plt.xticks(rotation=75)

plt.show()

# %% [markdown]
# Top 10 States by Number of Orders

# %%
top_states = df['State'].value_counts().head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    x=top_states.index,
    y=top_states.values
)

plt.title("Top 10 States by Number of Orders")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Sales by Ship Mode

# %%
ship_sales = df.groupby('Ship_Mode')['Sales'].sum()

plt.figure(figsize=(8,5))

ship_sales.plot(kind='pie', autopct='%1.1f%%')

plt.title("Sales Share by Ship Mode")
plt.ylabel("")

plt.show()

# %% [markdown]
# Sales by Region (Pie Chart)

# %%
region_sales = df.groupby('Region')['Sales'].sum()

plt.figure(figsize=(7,7))

region_sales.plot(kind='pie', autopct='%1.1f%%')

plt.title("Regional Sales Distribution")
plt.ylabel("")

plt.show()

# %% [markdown]
# Business Insights

# %% [markdown]
# # Business Insights
#
# 1. Technology category contributes significantly to overall sales.
#
# 2. The West region generates the highest sales among all regions.
#
# 3. Standard Class is the most preferred shipping mode.
#
# 4. A small group of customers contributes a large portion of total sales.
#
# 5. Some products generate very low sales and may require promotional strategies.
#
# 6. Sales vary across states, indicating regional differences in demand.
#
# 7. Monthly sales trends help identify seasonal business patterns.

# %% [markdown]
# Business Recommendations

# %% [markdown]
# # Business Recommendations
#
# 1. Focus marketing efforts on high-performing regions.
#
# 2. Reward top customers through loyalty programs.
#
# 3. Promote low-selling products using discounts and bundled offers.
#
# 4. Optimize inventory based on monthly demand trends.
#
# 5. Improve shipping efficiency by enhancing the most-used shipping methods.

# %% [markdown]
# # Conclusion
#
# This project analyzed Superstore sales data using Python. The analysis included data cleaning, KPI evaluation, exploratory data analysis, sales trend analysis, customer segment analysis, regional performance, and product performance.
#
# The insights reveal customer preferences, regional sales trends, and high-performing products. These findings can support business decisions related to marketing, inventory planning, customer retention, and sales growth.

# %% [markdown]
# 1. Import Libraries
# 2. Load Dataset
# 3. Data Cleaning
# 4. Dataset Overview
# 5. KPI Analysis
# 6. Sales by Category
# 7. Sales by Region
# 8. Customer Segment Analysis
# 9. Ship Mode Analysis
# 10. Monthly Sales Trend
# 11. State Analysis
# 12. City Analysis
# 13. Product Analysis
# 14. Top Customers
# 15. Correlation Heatmap
# 16. Business Insights
# 17. Business Recommendations
# 18. Conclusion
